# %%
# Core Libraries 
import pandas as pd
import numpy as np

# For Plotly Graph
import plotly.graph_objects as go
import plotly.express as px

# %%
# For Data
import sys
sys.path.insert(0,"D:\dosyalar\Github\Finance_Project\Finance_Data_Sets")

import Data_Sets

# %% [markdown]
# ## Data

# %%
TSLA_ticker = Data_Sets.Yahoo_Finance("TSLA")
TSLA_Data   = TSLA_ticker.get_data()
TSLA_Data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667  \
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-05-05  163.970001  170.789993  163.509995  170.059998  170.059998
# 2023-05-08  173.720001  173.800003  169.190002  171.789993  171.789993
# 2023-05-09  168.949997  169.820007  166.559998  169.149994  169.149994
# 2023-05-10  172.550003  174.429993  166.679993  168.539993  168.539993
# 2023-05-11  168.699997  173.559998  166.789993  172.080002  172.080002
#
#                Volume
# Date
# ...

# %%
Ford_ticker = Data_Sets.Yahoo_Finance("F")
Ford_data   = Ford_ticker.get_data(start_date = "2010-06-29")
Ford_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High     Low  Close  Adj Close     Volume
# Date
# 2010-06-29  10.12  10.14   9.750   9.88   5.995849  124866100
# 2010-06-30  10.10  10.52  10.040  10.08   6.117221  182831300
# 2010-07-01  10.23  10.63  10.020  10.57   6.414587  153383000
# 2010-07-02  10.58  10.63  10.150  10.28   6.238595   71607100
# 2010-07-06  10.42  10.57  10.040  10.16   6.165772   81246900
# ...           ...    ...     ...    ...        ...        ...
# 2023-05-05  11.79  12.04  11.720  11.99  11.990000   64138800
# 2023-05-08  12.02  12.06  11.850  12.02  12.020000   49943800
# 2023-05-09  11.89  11.93  11.780  11.86  11.860000   42878300
# 2023-05-10  12.02  12.04  11.730  11.89  11.890000   49193100
# 2023-05-11  11.83  11.88  11.755  11.87  11.870000   42687664
#
# [3240 rows x 6 columns]

# %% [markdown]
# ## Graphs

# %%
PX_line_Tesla = px.line(TSLA_Data, x=TSLA_Data.index, y=TSLA_Data["Close"], title='Tesla Close Price')
PX_line_Ford = px.line(Ford_data, x=Ford_data.index, y= Ford_data["Close"], title="Ford Close Price")

display(PX_line_Tesla)
display(PX_line_Ford)

# %%
Go_Line = go.Figure()
Go_Line.add_trace(go.Line(x =TSLA_Data.index, y =TSLA_Data["Close"], name = "Tesla Co."))
Go_Line.add_trace(go.Line(x =Ford_data.index, y =Ford_data["Close"], name = "Ford Co."))
Go_Line.update_xaxes(title = "Date")
Go_Line.update_yaxes(title = "Close")
Go_Line.update_layout(title = "Tesla Co. and Ford Co. Close Prices")
Go_Line.show()
# Out:
# c:\Users\Batuhan\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
realtimedata = Data_Sets.Yahoo_Finance("TSLA").real_time_price() 
Go_Line_All = go.Figure()
Go_Line_All.add_trace(go.Line(x = TSLA_Data.index, y= TSLA_Data["Open"], name ="Open", line=dict(dash ="dot")))
Go_Line_All.add_trace(go.Line(x = TSLA_Data.index, y= TSLA_Data["High"], name ="High",line=dict(dash ="dash")))
Go_Line_All.add_trace(go.Line(x = TSLA_Data.index, y= TSLA_Data["Close"], name ="Close"))
Go_Line_All.add_trace(go.Line(x = TSLA_Data.index, y= TSLA_Data["Low"], name ="Low",line=dict(dash ="dashdot")))
Go_Line_All.update_xaxes(title = "Date")
Go_Line_All.update_yaxes(title = "Prices")
Go_Line_All.update_layout(title = f"{realtimedata}",xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

Go_Line_All.show()

# %%
Tickers = ["TSLA","AAPL","F","C","MCD","BA","IBM","BLK","MSFT","GOOG","GE"]

info = []
industry = []
for i in Tickers:
    tickers = Data_Sets.Yahoo_Finance(i)
    info_get = tickers.info()
    info.append(info_get)
for k in np.arange(0,len(info)):
    all_tickers_info = info[k]
    all_industry_get = all_tickers_info["Information"].get("industry")
    industry.append(all_industry_get)

industry = pd.DataFrame(industry)
industry["Tickers"] = Tickers
industry.columns =["Industry","Tickers"]

labels = industry["Industry"]
values = industry["Industry"].value_counts().to_list()
Go_Pie = go.Figure(data=[go.Pie(labels=labels, values=values)])
Go_Pie.update_layout(title = "Industry Distribution")
Go_Pie.show()

# %%
Go_Heatmap = go.Figure(go.Histogram2d(x =Ford_data.index, y=Ford_data["Close"],texttemplate= "%{z}"))
Go_Heatmap.show()

# %%
import plotly.io as pio

pio.templates.default = "plotly_dark"

PX_Scatter_Tesla = px.scatter(x=TSLA_Data.index, y=TSLA_Data["Close"])
PX_Scatter_Tesla.show()

# %%
Go_CandleStick = go.Figure(go.Candlestick(x=TSLA_Data.index, open=TSLA_Data["Open"],
                                          low=TSLA_Data["Low"],
                                          high=TSLA_Data["High"],
                                          close=TSLA_Data["Close"]))
Go_CandleStick.update_xaxes(title = "Date")
Go_CandleStick.update_yaxes(title = "Price")
Go_CandleStick.update_layout(title = "Tesla Co. Stock Prices",xaxis_rangeslider_visible=False)
Go_CandleStick.show()

# %%
Tesla = TSLA_Data
Tesla["MA-50"] = Tesla["Close"].rolling(50).mean()
Tesla["MA-100"] = Tesla["Close"].rolling(100).mean()
Tesla["MA-200"] = Tesla["Close"].rolling(200).mean()

Go_CandleStick_2 = go.Figure(go.Candlestick(x=TSLA_Data.index, open=TSLA_Data["Open"],
                                          low=TSLA_Data["Low"],
                                          high=TSLA_Data["High"],
                                          close=TSLA_Data["Close"], name ="Candle Stick"))
Go_CandleStick_2.add_trace(go.Line(x = Tesla.index, y=Tesla["MA-50"],marker_color="blue",name = "MA-50"))
Go_CandleStick_2.add_trace(go.Line(x = Tesla.index, y=Tesla["MA-100"],marker_color="black",name = "MA-100"))
Go_CandleStick_2.add_trace(go.Line(x = Tesla.index, y=Tesla["MA-200"],marker_color="pink",name = "MA-200"))
Go_CandleStick_2.update_xaxes(title = "Date")
Go_CandleStick_2.update_yaxes(title = "Price")
Go_CandleStick_2.update_layout(title = f"{realtimedata}",xaxis_rangeslider_visible=False, template ="seaborn")
Go_CandleStick_2.show()
# Out:
# c:\Users\Batuhan\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
Same_industry_Companies = ["ADBE","ACN","SONY","UBER","AMD","QCOM"] # Sector: Technology

DataSets = []

for i in Same_industry_Companies:   
    Company_Data = Data_Sets.Yahoo_Finance(i)
    Company_Data_get = Company_Data.get_data()
    DataSets.append(Company_Data_get)

Companies_Data_Sets = {}

for i in np.arange(0,len(DataSets)):
    Companies_Data_Sets[i] = pd.DataFrame(DataSets[i]["Close"])
    
Technology_Companies = pd.DataFrame()
Technology_Companies["Adobe Inc."] = Companies_Data_Sets[0]
Technology_Companies["Accenture plc"] = Companies_Data_Sets[1]
Technology_Companies["Sony Group Corporation"] = Companies_Data_Sets[2]
Technology_Companies["Uber Technologies, Inc."] = Companies_Data_Sets[3]
Technology_Companies["Advanced Micro Devices, Inc."] = Companies_Data_Sets[4]
Technology_Companies["QUALCOMM Incorporated"] = Companies_Data_Sets[5]
Technology_Companies = Technology_Companies[Technology_Companies.index > "2020-01-01"]
Technology_Companies.columns.name = "Company"
Technology_Companies
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Company     Adobe Inc.  Accenture plc  Sony Group Corporation
# Date
# 2020-01-02  334.429993     210.149994               69.059998  \
# 2020-01-03  331.809998     209.800003               68.080002
# 2020-01-06  333.709991     208.429993               69.110001
# 2020-01-07  333.390015     203.929993               70.199997
# 2020-01-08  337.869995     204.330002               70.459999
# ...                ...            ...                     ...
# 2023-05-05  348.399994     265.649994               93.860001
# ...

# %%
PX_Facet_Plots = px.line(Technology_Companies, facet_col="Company", facet_col_wrap=3)
PX_Facet_Plots.add_hline(y=1, line_dash="dot",
              annotation_text="Jan 1, 2020 baseline",
              annotation_position="bottom right")
PX_Facet_Plots.update_layout(title = "Technology Companies")

PX_Facet_Plots.show()
