# %%
# Core Libraries 
import pandas as pd
import numpy as np

#For Graph
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# For Data
import sys
sys.path.insert(0,"D:\dosyalar\Github\Finance_Project\Finance_Data_Sets")

import Data_Sets

# %% [markdown]
# ## Data

# %%
TSLA_ticker = Data_Sets.Yahoo_Finance("TSLA")
TSLA_Data   = TSLA_ticker.get_data()
TSLA_Data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667  \
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-05-10  172.550003  174.429993  166.679993  168.539993  168.539993
# 2023-05-11  168.699997  173.570007  166.789993  172.080002  172.080002
# 2023-05-12  176.070007  177.380005  167.229996  167.979996  167.979996
# 2023-05-15  167.660004  169.759995  164.550003  166.350006  166.350006
# 2023-05-16  165.649994  169.520004  164.350006  166.520004  166.520004
#
#                Volume
# Date
# ...

# %%
Ford_ticker = Data_Sets.Yahoo_Finance("F")
Ford_data   = Ford_ticker.get_data(start_date = "2010-06-29")
Ford_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2010-06-29  10.12  10.14   9.75   9.88   5.995849  124866100
# 2010-06-30  10.10  10.52  10.04  10.08   6.117225  182831300
# 2010-07-01  10.23  10.63  10.02  10.57   6.414585  153383000
# 2010-07-02  10.58  10.63  10.15  10.28   6.238596   71607100
# 2010-07-06  10.42  10.57  10.04  10.16   6.165773   81246900
# ...           ...    ...    ...    ...        ...        ...
# 2023-05-10  12.02  12.04  11.73  11.89  11.890000   49193100
# 2023-05-11  11.83  11.88  11.76  11.87  11.870000   43030800
# 2023-05-12  11.93  11.94  11.65  11.67  11.670000   45100700
# 2023-05-15  11.70  11.72  11.59  11.64  11.640000   53197000
# 2023-05-16  11.55  11.58  11.24  11.25  11.250000   60413300
#
# [3243 rows x 6 columns]

# %%
Same_industry_Companies = ["ADBE","ACN","SONY","UBER","AMD","QCOM"] # Sector: Technology

DataSets = []

for i in Same_industry_Companies:   
    Company_Data = Data_Sets.Yahoo_Finance(i)
    Company_Data_get = Company_Data.get_data()
    DataSets.append(Company_Data_get)

Companies_Data_Sets = {}

for i in np.arange(0,len(DataSets)):
    Companies_Data_Sets[i] = pd.DataFrame(DataSets[i]["Close"])
    
Technology_Companies = pd.DataFrame()
Technology_Companies["Adobe Inc."] = Companies_Data_Sets[0]
Technology_Companies["Accenture plc"] = Companies_Data_Sets[1]
Technology_Companies["Sony Group Corporation"] = Companies_Data_Sets[2]
Technology_Companies["Uber Technologies, Inc."] = Companies_Data_Sets[3]
Technology_Companies["Advanced Micro Devices, Inc."] = Companies_Data_Sets[4]
Technology_Companies["QUALCOMM Incorporated"] = Companies_Data_Sets[5]
Technology_Companies = Technology_Companies[Technology_Companies.index > "2020-01-01"]
Technology_Companies.columns.name = "Company"
Technology_Companies
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Company     Adobe Inc.  Accenture plc  Sony Group Corporation
# Date
# 2020-01-02  334.429993     210.149994               69.059998  \
# 2020-01-03  331.809998     209.800003               68.080002
# 2020-01-06  333.709991     208.429993               69.110001
# 2020-01-07  333.390015     203.929993               70.199997
# 2020-01-08  337.869995     204.330002               70.459999
# ...                ...            ...                     ...
# 2023-05-10  344.019989     268.890015               93.430000
# ...

# %%
Tickers = ["TSLA","AAPL","F","C","MCD","BA","IBM","BLK","MSFT","GOOG","GE"]

info = []
industry = []
for i in Tickers:
    tickers = Data_Sets.Yahoo_Finance(i)
    info_get = tickers.info()
    info.append(info_get)
for k in np.arange(0,len(info)):
    all_tickers_info = info[k]
    all_industry_get = all_tickers_info["Information"].get("industry")
    industry.append(all_industry_get)

industry = pd.DataFrame(industry)
industry["Tickers"] = Tickers
industry.columns =["Industry","Tickers"]
industry
# Out:
#                            Industry Tickers
# 0                Auto Manufacturers    TSLA
# 1              Consumer Electronics    AAPL
# 2                Auto Manufacturers       F
# 3                 Banks—Diversified       C
# 4                       Restaurants     MCD
# 5               Aerospace & Defense      BA
# 6   Information Technology Services     IBM
# 7                  Asset Management     BLK
# 8           Software—Infrastructure    MSFT
# 9    Internet Content & Information    GOOG
# 10   Specialty Industrial Machinery      GE

# %% [markdown]
# ## Graphs

# %%
colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'brown', 'pink', 'gray', 'black', 'white']

# %%
realtimedata = Data_Sets.Yahoo_Finance("TSLA").real_time_price()
realtimedata
# Out:
# 'Company Name: Tesla, Inc. (TSLA), Price: 161.20, Price change: (+0.37%), Price Change Percantage: +0.59, '

# %%
Line_graph = plt.style.use('dark_background')
Line_graph = TSLA_Data["Close"].plot(kind="line", figsize=(20,10),color='red')
Line_graph = plt.title(f"Tesla Co. {realtimedata}",fontsize=16)
Line_graph = plt.ylabel("Price", fontsize =10)
Line_graph = plt.legend(loc='upper right',title = "Columns")
Line_graph = sns.set(style='whitegrid')

# %%
Line_graph_multi = plt.style.use('dark_background')
Line_graph_multi  = TSLA_Data["Close"].plot(kind="line", figsize=(20,10),color='red', label = "Tesla Close")
Line_graph_multi  = Ford_data["Close"].plot(kind="line", color = "yellow", label = "Ford Close")
Line_graph_multi  = plt.title("Tesla Co. & Ford Co.",fontsize=16)
Line_graph_multi  = plt.ylabel("Price", fontsize =10)
Line_graph_multi  = plt.legend(loc='upper right',title = "Columns")
Line_graph_multi  = sns.set(style='whitegrid')

# %%
Line_graph_tech  = plt.style.use('classic')
Line_graph_tech  = Technology_Companies.plot(kind="line", figsize=(20,10))
Line_graph_tech  = plt.title("Technology Companies",fontsize=16)
Line_graph_tech  = plt.ylabel("Price", fontsize =10)
Line_graph_tech  = plt.legend(loc='upper right',title = "Columns",fontsize=10)
Line_graph_tech  = sns.set(style='whitegrid')

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20, 10))

fig = axes[0,0].plot(Technology_Companies["Adobe Inc."])
fig = axes[0,1].plot(Technology_Companies["Accenture plc"])
fig = axes[1,0].plot(Technology_Companies["Advanced Micro Devices, Inc."])
fig = axes[1,1].plot(Technology_Companies["Uber Technologies, Inc."])
fig = axes[2,0].plot(Technology_Companies["Sony Group Corporation"])
fig = axes[2,1].plot(Technology_Companies["QUALCOMM Incorporated"])

fig = axes[0,0].set_title("Adobe Inc.")
fig = axes[0,1].set_title("Accenture plc")
fig = axes[1,0].set_title("Advanced Micro Devices, Inc.")
fig = axes[1,1].set_title("Uber Technologies, Inc.")
fig = axes[2,0].set_title("Sony Group Corporation")
fig = axes[2,1].set_title("QUALCOMM Incorporated")

baseline = 15


for ax in axes.flatten():
    fig = ax.axhline(y=baseline, color='red', linestyle='--')
    

fig = plt.subplots_adjust(hspace=0.5)
fig = plt.legend(["Lines","Baseline"],loc='center left',title = "Columns",fontsize=12,bbox_to_anchor=(1, 3.75))
fig = plt.suptitle("Technology Companies",fontsize=16)

# Show the figure
plt.show()

# %%
labels = industry["Industry"].unique().tolist()
values = industry["Industry"].value_counts().to_list()
fig = plt.style.use('dark_background')
fig = plt.pie(values,labels=labels,autopct='%1.1f%%')
fig = plt.legend(loc='upper right',title = "Industry",fontsize=12,bbox_to_anchor=(1.8,0.8))
fig = plt.axis('equal')
